# %% [markdown]
# # Import

# %% [markdown]
# read later https://towardsdatascience.com/set-your-jupyter-notebook-up-right-with-this-extension-24921838a332

# %%
from gtts import gTTS
import os
import wikipedia
import os
from google.cloud import translate
#from ClassText2Speech import speak_chinese
from xpinyin import Pinyin
import jieba
import jieba.posseg as pos
import jieba.analyse as ana
import sys
from importlib import *
from collections import Counter
import re
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
#import matplotlib.pyplot as plt
#%matplotlib inline

# %%
# List of common words that should be excluded from analysis
jieba_stop_words = ["、","。","〈","〉","《","》","一","一些","一何","一切","一则",
                    "一方面","一旦","一来","一样","一般","一转眼","七","万一","三",
                    "上","上下","下","不","不仅","不但","不光","不单","不只","不外乎",
                    "不如","不妨","不尽","不尽然","不得","不怕","不惟","不成","不拘",
                    "不料","不是","不比","不然","不特","不独","不管","不至于","不若",
                    "不论","不过","不问","与","与其","与其说","与否","与此同时","且",
                    "且不说","且说","两者","个","个别","中","临","为","为了","为什么",
                    "为何","为止","为此","为着","乃","乃至","乃至于","么","之","之一",
                    "之所以","之类","乌乎","乎","乘","九","也","也好","也罢","了","二",
                    "二来","于","于是","于是乎","云云","云尔","五","些","亦","人","人们",
                    "人家","什","什么","什么样","今","介于","仍","仍旧","从","从此","从而",
                    "他","他人","他们","他们们","以","以上","以为","以便","以免","以及",
                    "以故","以期","以来","以至","以至于","以致","们","任","任何","任凭",
                    "会","似的","但","但凡","但是","何","何以","何况","何处","何时","余外",
                    "作为","你","你们","使","使得","例如","依","依据","依照","便于","俺",
                    "俺们","倘","倘使","倘或","倘然","倘若","借","借傥然","假使","假如",
                    "假若","做","像","儿","先不先","光是","全体","全部","八","六","兮",
                    "共","关于","关于具体地说","其","其一","其中","其二","其他","其余",
                    "其它","其次","具体地说","具体说来","兼之","内","再","再其次","再则",
                    "再有","再者","再者说","再说","冒","冲","况且","几","几时","凡","凡是",
                    "凭","凭借","出于","出来","分","分别","则","则甚","别","别人","别处","别是",
                    "别的","别管","别说","到","前后","前此","前者","加之","加以","即","即令","即使",
                    "即便","即如","即或","即若","却","去","又","又及","及","及其","及至","反之",
                    "反而","反过来","反过来说","受到","另","另一方面","另外","另悉","只","只当",
                    "只怕","只是","只有","只消","只要","只限","叫","叮咚","可","可以","可是",
                    "可见","各","各个","各位","各种","各自","同","同时","后","后者","向","向使",
                    "向着","吓","吗","否则","吧","吧哒","含","吱","呀","呃","呕","呗","呜","呜呼",
                    "呢","呵","呵呵","呸","呼哧","咋","和","咚","咦","咧","咱","咱们","咳","哇",
                    "哈","哈哈","哉","哎","哎呀","哎哟","哗","哟","哦","哩","哪","哪个","哪些",
                    "哪儿","哪天","哪年","哪怕","哪样","哪边","哪里","哼","哼唷","唉","唯有","啊",
                    "啐","啥","啦","啪达","啷当","喂","喏","喔唷","喽","嗡","嗡嗡","嗬","嗯","嗳",
                    "嘎","嘎登","嘘","嘛","嘻","嘿","嘿嘿","四","因","因为","因了","因此","因着",
                    "因而","固然","在","在下","在于","地","基于","处在","多","多么","多少","大",
                    "大家","她","她们","好","如","如上","如上所述","如下","如何","如其","如同","如是",
                    "如果","如此","如若","始而","孰料","孰知","宁","宁可","宁愿","宁肯","它","它们",
                    "对","对于","对待","对方","对比","将","小","尔","尔后","尔尔","尚且","就","就是",
                    "就是了","就是说","就算","就要","尽","尽管","尽管如此","岂但","己","已","已矣","巴",
                    "巴巴","年","并","并且","庶乎","庶几","开外","开始","归","归齐","当","当地","当然",
                    "当着","彼","彼时","彼此","往","待","很","得","得了","怎","怎么","怎么办","怎么样",
                    "怎奈","怎样","总之","总的来看","总的来说","总的说来","总而言之","恰恰相反","您","惟其",
                    "慢说","我","我们","或","或则","或是","或曰","或者","截至","所","所以","所在","所幸",
                    "所有","才","才能","打","打从","把","抑或","拿","按","按照","换句话说","换言之","据",
                    "据此","接着","故","故此","故而","旁人","无","无宁","无论","既","既往","既是","既然",
                    "日","时","时候","是","是以","是的","更","曾","替","替代","最","月","有","有些","有关",
                    "有及","有时","有的","望","朝","朝着","本","本人","本地","本着","本身","来","来着","来自",
                    "来说","极了","果然","果真","某","某个","某些","某某","根据","欤","正值","正如","正巧",
                    "正是","此","此地","此处","此外","此时","此次","此间","毋宁","每","每当","比","比及",
                    "比如","比方","没奈何","沿","沿着","漫说","焉","然则","然后","然而","照","照着","犹且",
                    "犹自","甚且","甚么","甚或","甚而","甚至","甚至于","用","用来","由","由于","由是",
                    "由此","由此可见","的","的确","的话","直到","相对而言","省得","看","眨眼","着","着呢",
                    "矣","矣乎","矣哉","离","秒","竟而","第","等","等到","等等","简言之","管","类如",
                    "紧接着","纵","纵令","纵使","纵然","经","经过","结果","给","继之","继后","继而",
                    "综上所述","罢了","者","而","而且","而况","而后","而外","而已","而是","而言","能",
                    "能否","腾","自","自个儿","自从","自各儿","自后","自家","自己","自打","自身","至",
                    "至于","至今","至若","致","般的","若","若夫","若是","若果","若非","莫不然","莫如",
                    "莫若","虽","虽则","虽然","虽说","被","要","要不","要不是","要不然","要么","要是",
                    "譬喻","譬如","让","许多","论","设使","设或","设若","诚如","诚然","该","说","说来",
                    "请","诸","诸位","诸如","谁","谁人","谁料","谁知","贼死","赖以","赶","起","起见",
                    "趁","趁着","越是","距","跟","较","较之","边","过","还","还是","还有","还要","这",
                    "这一来","这个","这么","这么些","这么样","这么点儿","这些","这会儿","这儿","这就是说",
                    "这时","这样","这次","这般","这边","这里","进而","连","连同","逐步","通过","遵循",
                    "遵照","那","那个","那么","那么些","那么样","那些","那会儿","那儿","那时","那样",
                    "那般","那边","那里","都","鄙人","鉴于","针对","阿","除","除了","除外","除开",
                    "除此之外","除非","随","随后","随时","随着","难道说","零","非","非但","非徒","非特",
                    "非独","靠","顺","顺着","首先","︿","！","＃","＄","％","＆","（","）","＊","＋",
                    "，","０","１","２","３","４","５","６","７","８","９","：",
                    "；","＜","＞","？","＠","［","］","｛","｜","｝","～","￥","\n", " ",'借傥', '兼',
                    '前', '唷', '啪', '啷', '喔', '天', '始', '漫', '然', '特', '竟', '莫', '见', '设', '达',
                   "!" ,"#", "$", "%","&", "(",")","+", "-","/","=","'", ",", "?","他們","並且",
                   "擁有","擁有","'一個'"]

# %% [markdown]
# ## Connect API

# %%
#api key for google api
## you'll need to get your own API key using google cloud console and replace the path name
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/db/Desktop/APIKeys/LearnChinese.json"

# %%
#Instantiate Frequently Used 
p = Pinyin()

# %%
# Jeiba can only work with utf-8 encoding so we need to create a file that is constantly rewritten
f = open("myfile.txt", "w", encoding="utf-8")
f.write("")
f.close()

# %% [markdown]
# # Google Translate API  [Read-The-Docs](https://www.geeksforgeeks.org/python-docstrings/ )

# %% [markdown]
# ## Simple English to Chinese Translation Function

# %%
#translates English to Chinese for the initial search of wikipedia in language being learned
def english2chinese(topic, display=False):
    """ Translates a word or words from English into Traditional Mandarin"""
    # Instantiates a client
    translate_client = translate.Client()
    text = topic
    # Defines the target language
    target = 'zh-TW'
    # Translates some text into traditional Chinese
    translation = translate_client.translate(text, target_language=target)
    text_ = translation['translatedText']
    if display == True:
        print(text_)
        return text_
    else:
        return text_

# %% [markdown]
# ### Sanity Check

# %%
# sanity check
# english2chinese('Batman') #'蝙蝠俠'

# %% [markdown]
# ## Simple Chinese to English Translation Function

# %%
# translates Chinese to English
def chinese2english(topic):
    # Instantiates a client
    translate_client = translate.Client()
    text = topic
    # Defines the target language
    target = 'en'
    # Translates some text into traditional Chinese
    translation = translate_client.translate(text, target_language=target)
    text_ = translation['translatedText']
    if display == True:
        print(text_)
        return text_
    else:
        return text_

# %% [markdown]
# ### Sanity Check

# %%
# Sanity Check!
#english2chinese('Batman') #'蝙蝠俠'

# %% [markdown]
# ## Speech-to-Text

# %% [markdown]
# ## English To Chinese

# %%
def e2c_say_anything():
    translate_client = translate.Client()
    text = input('What word would you like to say in Chinese(Mandarin)：')
    # Defines the target language
    target = 'zh-TW'
    # Translates some text into traditional Chinese
    translation = translate_client.translate(text, target_language=target)
    text_ = translation['translatedText']
    # Build the voice request, select the language code ("en-US") and the ssml
    # voice gender ("neutral")
    
    #add pinyin
    pinyin_with_numbers = p.get_pinyin(text_, tone_marks='numbers')
    tts = gTTS(text=text_, lang='zh-TW')
    tts.save("good.mp3")
    
    print("Input: {}".format(text))
    print("Traditional Chinese Translation: {}".format(text_))
    print("Pinyin Translation with tone numbers: {}".format(pinyin_with_numbers))
    return os.system("mpg321 good.mp3")

# %% [markdown]
# ### Sanity Check

# %%
# Sanity Check
# e2c_say_anything()
# What word would you like to say in Chinese(Mandarin)：Batman
# Input: Batman
# Traditional Chinese Translation: 蝙蝠俠
# Pinyin Translation with tone numbers: bian1-fu2-xia2

# %% [markdown]
# ## Chinese To English

# %%
def c2e_say_anything(text):
    translate_client = translate.Client()
    text = text
    # Defines the target language
    target = 'en'
    # Translates some text into traditional Chinese
    translation = translate_client.translate(text, target_language=target)
    text_ = translation['translatedText']
    # Build the voice request, select the language code ("en-US") and the ssml
    # voice gender ("neutral")
    
    
    tts = gTTS(text=text_, lang='en')
    tts.save("good.mp3")
    
    print("Input: {}".format(text))
    print("Output: {}".format(text_))
    return os.system("mpg321 good.mp3")

# %% [markdown]
# ### Sanity Check

# %%
#Sanity Check
c2e_say_anything('蝙蝠俠')
# What Chinese word would you like to say in English?：蝙蝠俠
# Input: 蝙蝠俠
# Output: Batman
# Out:
# Input: 蝙蝠俠
# Output: Batman
# 0

# %% [markdown]
# # Wikipedia Search

# %%
def search_wikipedia(topic, display=False,results=3):
    wikipedia.set_lang('zh')
    search_phrase = english2chinese(topic)
    pages = wikipedia.search(search_phrase, results=results)
    if display == True:
        print('the pages in native language', pages)
        return pages
    else:
        return pages

# %%
# Sanity Check
# search_wikipedia('Batman')
# ['蝙蝠俠',
#  '蝙蝠俠：開戰時刻',
#  '蝙蝠俠：高譚騎士',
#  '樂高蝙蝠俠電影',
#  '蝙蝠侠 (动画影集)',
#  '蝙蝠侠归来',
#  '蝙蝠俠對超人：正義曙光',
#  '永远的蝙蝠侠',
#  '蝙蝠侠与罗宾 (电影)',
#  '蝙蝠俠：黑暗騎士歸來']

# %%
def get_content(topic):
    """Takes a topic Parameter and returns the wikipedia page that best matches that topic in Chinese"""
    wikipedia.set_lang('zh')
    search_phrase = english2chinese(topic)
    wiki_page = wikipedia.page(search_phrase,preload=True)
    return wiki_page.content

# %%
#get_content('Batman')

# %%
def wikipedia_page_choices(topic, language='en'):
    pages = search_wikipedia(topic)
    translate_client = translate.Client()
    target_en = language
    print('Titles of wikipedia page')
    for page in pages:
            english_translation = translate_client.translate(page, target_language=target_en)
            english_text = english_translation['translatedText']
            print(english_text)

# %%
#sanity check
wikipedia_page_choices('Batman')
# #The following pages are in Chinese but the titles are translated into English
# Batman
# Batman: The moment of war
# Batman: Gotham Knight
# Lego Batman Movie
# Batman (Animation Album)
# Batman returns
# Batman vs. Superman: The Light of Justice
# Forever Batman
# Batman and Robin (movie)
# Batman: Return of the Dark Knight
# Out:
# Titles of wikipedia page
# Batman
# Batman: The moment of war
# Batman: Gotham Knight

# %%
# rerun this cell to clear the myfile.txt without having to rerun all previous cells
f = open("myfile.txt", "w", encoding="utf-8")
f.write("")
f.close()

# %%
def getChinese(content):
    content = content.decode("utf-8") # convert content from str to unicode
    filtrate = re.compile(u'[^\u4E00-\u9FA5]') # non-Chinese unicode range
    content = filtrate.sub(r'', content) # remove all non-Chinese characters
    content = content.encode("utf-8") # convert unicode back to str
    return content

# %%
corpus = []

def combine_wikipedia_pages(query, suggestion=True):
    translated_query = english2chinese(query)
    titles = wikipedia.search(translated_query)
    filter('', titles)
    for title in titles:
        webpage = wikipedia.page(title)
        content = webpage.content
#         content = getChinese(content)
        #remove links
        #content = re.sub("http://[a-zA-z./\d]*"," ",content)
        # remove emojis
        #content = re.sub("\[.{0,12}\]"," ",content)
        #remove digits
        #content = re.sub("\d","",content)
        # remove elipses
        #content = re.sub("\.*"," ",content)
        #extract and remove all english characters
        english = re.findall("[a-z]+",content)
        content = re.sub("[a-z]+","",content)
        print("page added to content")
        f = open("myfile.txt", "a")
        f.write(str(content))
        f.close()
        
        corpus.append(content)
        
    print("process finished, all content stored in myfile.txt")

# %%
#sanity check
combine_wikipedia_pages('NFL')
# Out:
# page added to content
# page added to content
# page added to content
# page added to content
# page added to content
# page added to content
# page added to content
# page added to content
# page added to content
# page added to content
# process finished, all content stored in myfile.txt

# %%
#read in the text file
with open('myfile.txt','r')as myfile:
    data=myfile.read()

# %%
#segement and save 
seg_list = jieba.cut(data, cut_all=False)

# %%
seg_list = [str(word) for word in seg_list if not str(word) in jieba_stop_words]

# %%
new_text = ("".join(seg_list))

# %%
new_text
# Out:
# '国家美式足球联盟NFLNFL世界最大职业美式足球联盟世界最具商业价值体育联盟目前联盟共有32支球队分为两个联会美國美式足球聯會國家美式足球聯會每个联会四个分区组成每个分区四支球队例行赛季每支球队於每年912月間17週内實行16场比赛比賽通常選在週日週一週四例行赛季後每个联会共有六支球队進入季後赛包括各分區冠軍4隊戰績較佳2隊通常稱為外卡WC隊三轮淘汰赛两个联会冠军預定球場舉辦超級盃比赛争夺後总冠军超级盃举办一周會奥兰多舉辦職業盃明星賽兩聯會各選出明星選手联盟最早1920美国职业美式橄榄球協会APFA成立於1922128改名为國家美式足球聯盟NFL國家美式足球聯盟北美四大職業運動現有隊伍NFL目前共有32支球隊不同於美國職棒大聯盟國家籃球協會國家冰球聯盟聯盟加拿大並沒有隊伍加拿大加拿大加式足球聯盟大部分球隊主場位於美國大城市會區綠灣包裝工主場位於威斯康辛州最大城市為密爾瓦基城市綠灣達拉斯牛仔為目前美國賺錢職業運動隊伍2019市值為50億美元2018球季以來NFL球隊名單季賽結構目前NFL賽季组成A44場國家美式足球聯盟表演賽季或季前賽從七月下旬八月下旬A1616場17個禮拜常規賽從九月12A1212隊季後賽競爭從一月開始二月上旬超級盃達高潮季前賽夏天觀賞大部分NFL隊伍進行四場季前賽PG從八月上旬九月上旬兩場「特別」季前賽—職業美式足球名人堂賽PFHFG美國盃AB並不計算四場比賽內參加這兩項特別比賽球隊將會結束季前賽時參加5場表演賽這些比賽對於尚未習慣於大群球迷面前進行比賽新人選手來說非常有用管理部門也常用這些比賽來評估新簽約選手價值球队主力通常一場比賽上場一節避免受傷常規賽常規賽每隊17周之內進行16場對決當中6場為與該聯會同組其餘3隊進行主客兩回合比賽其餘十場賽事則與聯會同組以外比賽於美式足球賽季運動短近乎每場比賽「必須獲勝」當中引發不少宿敵對抗每次華盛頓紅人對達拉斯牛仔令全國氣氛升溫巨人遇上噴射機紐約德比NFL一場經典對抗賽季後賽季後賽12支隊伍進行比賽來決定最後參加超級碗兩支隊伍一場過淘汰賽TB由聯盟兩聯會6支球隊進行比賽美国美式足球联会與国家美式足球联会來兩聯會四個分區冠軍為每個分區內最佳例行賽戰績球隊依據例行賽戰績編為第一種子第四種子兩聯會兩支外卡資格球隊為聯會非分區冠軍擁最佳勝率球隊將分為第五種子第六種子第三第六種子第四第五種子將在季後第一輪碰面稱作外卡季後賽聯盟近幾年使用外卡週末稱呼聯會第一第二種子第一輪免賽權代表這些隊伍將自動晉級第二輪—分區季後賽面對外卡倖存者季後賽任一輪中最高存活種子隊總與最低存活種子隊進行比賽一場季後賽較高種子隊主場優勢比賽將於較高種子隊主場舉行兩支從分區賽存活隊伍將聯會冠軍賽碰面勝者將在超級碗對一聯會冠軍超級盃超級盃季後賽總決賽由美國美式足球聯會對國家美式足球聯會每年會指定球場舉行球隊未必「主場優勢」現時通常二月第一個星期日舉行超級盃美國最高收視體育運動賽事外還有中場表現作焦點電視轉播NFL電視轉播權美國運動裡有利潤最高價的美國各項娛樂事業因為多樣化趨勢廣播有線電視網裡體育運動保持其為少數娛樂事業只能夠保證非常多樣化觀眾群還能保證觀眾會現時收看產業每年超级碗通常為該收視率最高節目尼爾森收視調查T10排行榜中有四個超級盃電視網買NFL轉播權方式來提高自我形象現今電視合約從2006球季開始例行賽由五家電視網轉播包括哥倫比亞廣播公司CBS福克斯廣播公司F國家廣播公司NBCESPNNFL電視網地方性轉播比賽禮拜天於CBSFOX轉播國聯美聯比賽各一場客隊跨聯會比賽決定轉播站全國轉播比賽包括周日夜晚比賽NBC周一夜晚比賽ESPN週四夜晚NFL開踢比賽每年達拉斯牛仔底特律雄獅感恩節比賽還有2006球季選擇週四週六比賽NFL電視網轉播一個全由NFL附屬組織衛星廣播公司DTV提供NFLST一個訂戶套裝服務允許訂戶收看大部分週日日間地方比賽這個套裝服務美國對DTV獨家加拿大NFLST衛星有線電視網提供無線廣播每支NFL球隊會球隊專屬無線廣播網全國性NFL廣播WO廣播網WO美國運動廣播收聽WO轉播週日週一夜晚美式橄榄球季後賽职业碗美國運動廣播則於例行賽季週日轉播兩場下午比賽NFL同時與SSRSSR簽約提供比賽新聞分析評論全方位新聞報導球員合約酬勞NFL球員為稱作國家美式足球聯盟球員協會NFLPANFLPA工會成員NFLPA為球員與聯盟協商最低合約這個合約稱作共同契約協議CBACBA左右聯盟內球員各別合約協商核心文件現今共同契約協議於1993開始實行1998修訂NFL從1987賽季沒有罷工行為比美國職棒大聯盟國家籃球協會國家冰球聯盟來久現今共同契約協議於2006年賽季結束後到期球員分成三種等級來爭取合約選秀會挑選過球員見第一年未出賽只能與挑選隊伍協商合約期限內合約無法協商完成球員唯一權力拒絕出賽期限終止球員們常用拒絕出賽手段來威脅選上球隊約翰·愛爾威JE巴爾摩烏鴉於1983挑中拒絕為烏鴉出賽烏鴉最後把交易丹佛野馬愛爾威同意出賽波·傑克森BJ拒絕出賽一整個1986球季不願為選上坦帕灣海盜效力於隔重新加入選秀隨後被洛杉磯突襲者選上於聯盟內出賽三至五個完整球季合約已經到期球員稱作「受限自由球員」RFA見受限制權利與球隊協商合約於聯盟內出賽多個完整球季合約已經到期球員稱作「受限自由球員」UFA見它們受限制權利與球隊進行合約協商球隊可能會一年內指定單一球員為「特別標籤球員」FP見排除許多球員協商權利這是一條受限制球團權利每年影響手指數的出來內球員共同契約協議包括以下:聯盟最低薪資T薪資上限T年度學生選秀T自由球員規則R""讓渡規則W薪資一個球員薪水根據共同契約協議包括「金錢財產投資借款『可能授予』NFL球員報酬」排除像是保險退休金利益薪資包含年薪當球員與球團簽下合約時一次性「簽約加碼」薪資上限目的於見簽約加碼分布合約生涯內會於簽約該付來球員合約並不完全肯定球團需球員還在球團內時合約給付薪資當球員開除離開因為原因留在隊上合約未付餘額無效球員不會得到進一步報酬共同契約協議為球員建立最低薪資隨著球員資而增加球員經紀可能會與球團協商高薪資經常NFL2005賽季高薪球員為亞特蘭大獵鷹四分衛麥·維克MV年薪略低於800萬美元其合約總價值101億3000萬平均每年1300萬包括簽約加碼與年薪薪資上限薪資上限S定義為—每年球團花球員報酬花最高值見包括球員不同於聯盟NBA免除美國職棒大聯盟軟性薪資上限可補繳豪華稅NFL薪資上限屬於硬上限沒有一隊能夠超越上限NFL薪資上限一個公式來計算現今共同契約協議解釋為59.5%聯盟年度總計劃收入這個數字除以球隊總數即得每個球隊高薪資上限2006薪資上限為大約一隊1億200萬2007計畫上限將會提高1億900萬球團球員時常找出創意手段符合薪資上限規定早期「薪資加碼」私下給予球員大筆錢卻包含總體合約內這導致一條規定限制薪資加碼必須合約內每年比率相等一個球員因一個5年合約得到1000萬簽約加碼必須合約生涯內每年給予200萬1000萬已經合約第一年給予當球團開除球員簽約加碼終止分配總體餘額計算一季薪資內當球員「薪資」於開除後停止給付則不受此限球員合約傾向於變""這意味著合約並均分於包含時間內取而代之球員每年獲得越來越薪資一位球員簽下4價值1千萬合約第一年可能會獲得1百萬第二年2百萬第三年3百萬第四年4百萬球團於第一年後開除球員後三年並不計算於薪資簽約加碼總體餘額仍會計算球團開除球員計算球員完全球員遭到開除隔NFL選秀每年四月每支NFL隊伍企求獲得新球員加入而舉辦學生選秀稱作「NFL年度球員選擇會議」NFLAPSM更常稱為NFL選秀隊伍依據它們一季戰績倒轉排列戰績最差球隊第一順位第二差球隊第二順位以此類推兩種例外情形對於一季超級盃出賽球隊超級盃冠軍只會得到32順位超級盃輸家則得到31順位選秀進行七輪第一第三輪選秀週末週六舉行四至七輪於週日舉行球隊必須給予限制時間內做出選擇決定沒分配時間內完成順位後球隊可能於之前進行選秀這在2003發生於明尼蘇達維京人球隊將選秀權轉賣給球隊換取不同選秀權球員現金相關組合權利球員對球員交易鮮少於球季期間發生特別與北美三項職業運動較交易更常於選秀日當天進行1989有史以來具爭辯性選秀日交易發生—達拉斯牛仔將跑衛賀契爾·華克HW交易明尼蘇達維京人換取五位資深球員三年內六個選秀權牛仔會將這些選秀權來平衡附加選秀權資深球員交易這項交易直接結果選到許多明星幫助於1990年代贏得三次超級盃冠軍包括艾米特·史密斯ES羅塞·馬里蘭RM戴倫·伍得森DW第一順位選秀權通常會選走該年度新人裡各方面最佳球員這有時一定會發生因為球隊更常需求來選擇該球員方面能力比較不同位置球員一件難以做到事情即使如此第一輪挑中仍然一個榮耀全選秀會第一順位更是極大榮耀選秀會最後一順位球員戲稱為M.I無關緊要先生新港灘加州一道晚餐主題選中球員只能與選擇球隊協商合約權利交易時可能別隊協商選秀隊伍有一年時間簽下球員球團沒有這麼球員可能會重新加入選秀隊伍挑走波·傑可森BJ這種方式拒絕出賽一年而聞名自由球員根據共同契約協議解釋一個自由球員指沒與球隊合約關係完整自由權利去與球隊協商新合約自由球員分為兩種類型「限制」與「限制」一個球隊可能會「標籤」一個球員為「特別」「過渡」讓該球員額外條件權利協商合約這個「標籤」通常受限每年影響非常少數的球員NFL自由球員從一個稱作「計畫B自由球員制度」受限制自由球員系統運行於NFL19891992賽季從NFL1993賽季「計畫A自由球員制度」開始運行NFL自由球員制度受限自由球員一個3少於5年資球員稱作受限自由球員RFA球團NFL球團開出最高價碼與其續約球團封鎖簽約實質提供過最低門檻薪資強迫達成協議2006這些最低門檻一個球 ...

# %%
f=open('myfile.txt','w')
f.write(new_text)
f.close()

# %%
top20 = jieba.analyse.extract_tags(new_text, topK=20, withWeight=True)

# %%
top20
# Out:
# [('NFL', 0.25047275663036217),
#  ('美式足球', 0.22075564991150565),
#  ('聯盟', 0.1974064946324041),
#  ('球員', 0.16768938791354757),
#  ('球隊', 0.14009493167460935),
#  ('比賽', 0.13797228119469104),
#  ('超級', 0.13160432975493608),
#  ('一個', 0.08490601919673295),
#  ('美國', 0.072170116317223),
#  ('職業', 0.07004746583730467),
#  ('記錄', 0.06792481535738636),
#  ('國家', 0.061556863917631384),
#  ('聯會', 0.05943421343771306),
#  ('球團', 0.05518891247787641),
#  ('球季', 0.050943611518039764),
#  ('進行', 0.0445756600782848),
#  ('薪資', 0.042453009598366474),
#  ('季後賽', 0.038207708638529826),
#  ('合約', 0.038207708638529826),
#  ('開始', 0.0360850581586115)]

# %%
vocab = pd.DataFrame(top20, columns=['Chinese','Weight'])

# %%
vocab
# Out:
#    Chinese    Weight
# 0      NFL  0.250473
# 1     美式足球  0.220756
# 2       聯盟  0.197406
# 3       球員  0.167689
# 4       球隊  0.140095
# 5       比賽  0.137972
# 6       超級  0.131604
# 7       一個  0.084906
# 8       美國  0.072170
# 9       職業  0.070047
# 10      記錄  0.067925
# 11      國家  0.061557
# 12      聯會  0.059434
# 13      球團  0.055189
# 14      球季  0.050944
# 15      進行  0.044576
# 16      薪資  0.042453
# 17     季後賽  0.038208
# 18      合約  0.038208
# 19      開始  0.036085

# %%
def get_pinyin(word, tone_marks='numbers'):
    return p.get_pinyin(word, tone_marks='numbers')

# %%
vocab['Pinyin']= vocab['Chinese'].apply(get_pinyin)

# %%
vocab['English'] = vocab['Chinese'].apply(chinese2english)

# %%
vocab
# Out:
#    Chinese    Weight              Pinyin        English
# 0      NFL  0.250473                 NFL            NFL
# 1     美式足球  0.220756  mei3-shi4-zu2-qiu2       football
# 2       聯盟  0.197406         lian2-meng2       alliance
# 3       球員  0.167689          qiu2-yuan2         Player
# 4       球隊  0.140095           qiu2-dui4           team
# 5       比賽  0.137972            bi3-sai4           game
# 6       超級  0.131604           chao1-ji2          super
# 7       一個  0.084906             yi1-ge4            One
# 8       美國  0.072170           mei3-guo2  United States
# 9       職業  0.070047            zhi2-ye4         Career
# 10      記錄  0.067925             ji4-lu4      recording
# 11      國家  0.061557           guo2-jia1        country
# 12      聯會  0.059434          lian2-hui4     Federation
# 13      球團  0.055189          qiu2-tuan2         Pellet
# 14      球季  0.050944            qiu2-ji4         Season
# 15      進行  0.044576          jin4-xing2         get on
# 16      薪資  0.042453            xin1-zi1         Salary
# 17     季後賽  0.038208       ji4-hou4-sai4       Playoffs
# 18      合約  0.038208            he2-yue1       contract
# 19      開始  0.036085           kai1-shi3          Start

# %%
jieba_stop_words.append()
